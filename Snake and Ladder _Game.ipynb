# %%
import random as rd

# y and z both indicate the position of the player
y = 0  # y indicates the position of the player1
z = 0  # z indicates the position of the player2
k = 0  # Dummy condition to keep the loop running indefinitely

while k == 0:
    a = input("Ply1: Enter any key to roll: ")
    p1 = rd.choice([1, 2, 3, 4, 5, 6])
    print("You rolled the dice:", p1)

    # Condition for Player 1
    if y == 0 and p1 == 6:  # If player 1 is at position 0 and rolls a 6
        y = y + 1
        print("Your position is:", y)
    elif y >= 1:  # If player 1 is at a position greater than or equal to 1
        y = y + p1
        print("Your position is:", y)
        if y >= 100:
            print("Hey! Congratulations: YOU WON The Game")
            break
        elif y == 11 or y == 20 or y == 27 or y == 34 or y == 61 or y == 69 or y == 75 or y == 85 or y == 91:
            # If player 1 lands on a ladder position
            y = y + 9
            print("You got a ladder and your position is:", y)
        elif y == 23 or y == 45 or y == 72 or y == 89:
            # If player 1 lands on a snake position
            y = y - 5
            print("Snake bites you and your position is:", y)
    else:
        y = 0  # Reset player 1's position to 0 if none of the conditions are met

    b = input("Ply2: Enter anything to roll: ")
    p2 = rd.choice([1, 2, 3, 4, 5, 6])
    print("You rolled the dice:", p2)

    # Condition for Player 2
    if z == 0 and p2 == 6:  # If player 2 is at position 0 and rolls a 6
        z = z + 1
        print("Your position is:", z)
    elif z >= 1:  # If player 2 is at a position greater than or equal to 1
        z = z + p2
        print("Your position is:", z)
        if z >= 100:
            print("Hey! Congratulations: YOU WON The Game")
            break
        elif z == 20 or z == 27 or z == 34 or z == 61 or z == 69 or z == 75 or z == 85 or z == 91:
            # If player 2 lands on a ladder position
            z = z + 9
            print("You got a ladder and your position is:", z)
        elif z == 23 or z == 45 or z == 72 or z == 89:
            # If player 2 lands on a snake position
            z = z - 5
            print("Snake bites you and your position is:", z)
    else:
        z = 0  # Reset player 2's position to 0 if none of the conditions are met
# Out:
# Ply1: Enter any key to roll:
# You rolled the dice: 3
# Ply2: Enter anything to roll:
# You rolled the dice: 3
# Ply1: Enter any key to roll:
# You rolled the dice: 2
# Ply2: Enter anything to roll:
# You rolled the dice: 6
# Your position is: 1
# Ply1: Enter any key to roll:
# You rolled the dice: 1
# Ply2: Enter anything to roll:
# You rolled the dice: 3
# Your position is: 4
# Ply1: Enter any key to roll:
# You rolled the dice: 3
# Ply2: Enter anything to roll:
# You rolled the dice: 5
# Your position is: 9
# Ply1: Enter any key to roll:
# You rolled the dice: 6
# Your position is: 1
# Ply2: Enter anything to roll:
# You rolled the dice: 3
# Your position is: 12
# Ply1: Enter any key to roll:
# You rolled the dice: 1
# Your position is: 2
# Ply2: Enter anything to roll:
# You rolled the dice: 6
# Your position is: 18
# Ply1: Enter any key to roll:
# You rolled the dice: 3
# Your position is: 5
# Ply2: Enter anything to roll:
# You rolled the dice: 5
# Your position is: 23
# ...
